# %%
import sys
sys.path.insert(1, '../code/')
import pandas as pd
import time
import imdb
from extractData import *
from calcPastSuccess import *
dir(extractData)
di
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-249-1abe661a6f1c> in <module>
#       7 from calcPastSuccess import *
#       8 dir(extractData)
# ----> 9 dir(calcPastSuccess)
#
# NameError: name 'calcPastSuccess' is not defined

# %%
#Load in the data
train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")
#Look at all of the columns
print(train.columns)
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
#Drop columns we will not be using and inspect the head of df
train = train.drop(columns=[ 'homepage', 'poster_path', 'original_title', 'overview','tagline','Keywords'])
train.head(10)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN         0
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 9  10                                                NaN   6000000
#
#                                               genres    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...  tt0093743
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...  tt0431021
# 7                [{'id': 99, 'name': 'Documentary'}]  tt0391024
# 8  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...  tt0117110
# 9  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...  tt0310281
#
#   original_language  popularity  \
# 0                en    6.575393
# 1                en    8.248895
# 2                en   64.299990
# 3                hi    3.174936
# 4                ko    1.148070
# 5                en    0.743274
# 6                en    7.286477
# 7                en    1.949044
# 8                en    6.902423
# 9                en    4.672036
#
#                                 production_companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  [{'name': 'Ghost House Pictures', 'id': 768}, ...
# 7                                                NaN
# 8  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# 9  [{'name': 'Castle Rock Entertainment', 'id': 97}]
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15     93.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04    113.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14    105.0
# 3            [{'iso_3166_1': 'IN', 'name': 'India'}]       3/9/12    122.0
# 4      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09    118.0
# 5                                                NaN       8/6/87     83.0
# 6  [{'iso_3166_1': 'US', 'name': 'United States o...      8/30/12     92.0
# 7                                                NaN      1/15/04     84.0
# 8  [{'iso_3166_1': 'US', 'name': 'United States o...      2/16/96    100.0
# 9  [{'iso_3166_1': 'US', 'name': 'United States o...      4/16/03     91.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# 5           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 7  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...  Released
# 8           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 9           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
# 7                              Control Room
# 8                    Muppet Treasure Island
# 9                             A Mighty Wind
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6  [{'cast_id': 23, 'character': 'Clyde', 'credit...
# 7  [{'cast_id': 2, 'character': 'Himself', 'credi...
# 8  [{'cast_id': 1, 'character': 'Long John Silver...
# 9  [{'cast_id': 24, 'character': 'Jonathan Steinb...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075
# 7  [{'credit_id': '52fe47a69251416c750a0daf', 'de...   2586511
# 8  [{'credit_id': '52fe43c89251416c7501deb3', 'de...  34327391
# 9  [{'credit_id': '52fe45609251416c750545b3', 'de...  18750246

# %%
print(train.shape)
# Out:
# (3000, 17)

# %%
print(train.describe())
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
extract_data("hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-245-4461d405dc76> in <module>
# ----> 1 extract_data("hello")
#
# ~/GitHub/BOP/code/extractData.py in extract_data(str)
#       1 import re
#       2
# ----> 3 #function that uses a regex to extract data we need from various cols in dataset
#       4 def extract(str):
#       5     return re.findall("'name': \'(.+?)\'", str)
#
# NameError: name 're' is not defined

# %%
train.genres = train.genres.fillna("")
train.production_companies = train.production_companies.fillna("")
train.production_countries = train.production_countries.fillna("")
train.spoken_languages = train.spoken_languages.fillna("")

# %%
train['genres_reform'] = train['genres'].apply(lambda x: extract_data(x))
train['production_companies_reform'] = train['production_companies'].apply(lambda x: extract_data(x))
train['production_countries_reform'] = train['production_countries'].apply(lambda x: extract_data(x))
train['spoken_languages_reform'] = train['spoken_languages'].apply(lambda x: extract_data(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-244-d331879e87c2> in <module>
# ----> 1 train['genres_reform'] = train['genres'].apply(lambda x: extract_data(x))
#       2 train['production_companies_reform'] = train['production_companies'].apply(lambda x: extract_data(x))
#       3 train['production_countries_reform'] = train['production_countries'].apply(lambda x: extract_data(x))
#       4 train['spoken_languages_reform'] = train['spoken_languages'].apply(lambda x: extract_data(x))
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-244-d331879e87c2> in <lambda>(x)
# ----> 1 train['genres_reform'] = train['genres'].apply(lambda x: extract_data(x))
#       2 train['production_companies_reform'] = train['production_companies'].apply(lambda x: extract_data(x))
#       3 train['production_countries_reform'] = train['production_countries'].apply(lambda x: extract_data(x))
#       4 train['spoken_languages_reform'] = train['spoken_languages'].apply(lambda x: extract_data(x))
#
# ~/GitHub/BOP/code/extractData.py in extract_data(str)
#       1 import re
#       2
# ----> 3 #function that uses a regex to extract data we need from various cols in dataset
#       4 def extract(str):
#       5     return re.findall("'name': \'(.+?)\'", str)
#
# NameError: name 're' is not defined

# %%
train.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language  popularity  \
# 0                en    6.575393
# 1                en    8.248895
# 2                en   64.299990
# 3                hi    3.174936
# 4                ko    1.148070
#
#                                 production_companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3
# 4
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15     93.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04    113.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14    105.0
# 3            [{'iso_3166_1': 'IN', 'name': 'India'}]       3/9/12    122.0
# 4      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09    118.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
