# %%
import pandas as pd

# %%
#Load in the data
X = pd.read_csv("../data/trainFeatures.csv")
y = pd.read_csv("../data/trainTarget.csv")

# %%
print ('Train set:', X.shape,  y.shape)
print ('Test set:', X.shape,  y.shape)
# Out:
# Train set: (3000, 45) (3000, 1)

# %%
X.head()
# Out:
#           has_collection  budget_processed  log_budget  \
# 0  Belongs in Collection          14000000   16.454568
# 1  Belongs in Collection          40000000   17.504390
# 2      Not in Collection           3300000   15.009433
# 3      Not in Collection           1200000   13.997833
# 4      Not in Collection          16000000    0.000000
#
#                               genres_reform  num_genres  genre_rank  \
# 0                                ['Comedy']           1           9
# 1  ['Comedy', 'Drama', 'Family', 'Romance']           4           9
# 2                                 ['Drama']           1           4
# 3                     ['Thriller', 'Drama']           2          12
# 4                    ['Action', 'Thriller']           2          15
#
#    log_num_genres  log_genre_rank  has_homepage  in_english  ... log_num_crew  \
# 0        0.693147        2.302585             0           1  ...     4.290459
# ...

# %%
y.head()
# Out:
#    log_revenue
# 0    16.326300
# 1    18.370959
# 2    16.387512
# 3    16.588099
# 4    15.182615
